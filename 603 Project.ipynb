# %%
# %sh
pip install koalas
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: koalas in /databricks/python3/lib/python3.7/site-packages (1.0.1)
# ...
# </div>

# %%
# %sh
pip install --upgrade pip
pip install lxml
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already up-to-date: pip in /databricks/python3/lib/python3.7/site-packages (20.1.1)
# ...
# </div>

# %%
import databricks.koalas as ks
import lxml
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#years = range(2012, 2020)

#team_urls = ['adelaide', 'brisbanel', 'carlton', 'collingwood', 'essendon', 'fremantle', 'geelong', 'goldcoast',
#             'gws', 'hawthorn', 'melbourne', 'kangaroos', 'padelaide', 'richmond', 'stkilda', 'swans', 'westcoast',
#             'bullldogs']

#season_team_game_PI = []
#for year in years:
#    team_game_PI = []
#    for team in team_urls:
#        url = 'https://afltables.com/afl/stats/teams/'+team+'/'+str(year)+'_gbg.html'
#        PIGBG19 = ks.read_html(url)
#        team_PI = []
#        for PI in PIGBG19:
#          team_PI.append(PI)
#        team_game_PI.append(team_PI)
#    season_team_game_PI.append(team_game_PI)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#season_team_game_PI[0][0][0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Here is what Isabelle did.  The project starts here
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh
pip install pymongo
pip install pymongo[srv]
pip install pymongo[tls]
pip install dnspython
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: pymongo in /databricks/python3/lib/python3.7/site-packages (3.10.1)
# ...
# </div>

# %%
from pymongo import MongoClient
from pyspark.sql.types import *
import pyspark.sql
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#client = MongoClient(mongodb+srv://michael1:Data603UMBC@cluster0-t7ekj.mongodb.net/AFL_603_project_db.home_away?retryWrites=true&w=majority)
client = MongoClient("mongodb+srv://michael1:Data603UMBC@cluster0-t7ekj.mongodb.net/dataPI_db?retryWrites=true&w=majority")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
db = client.get_database('dataPI_db')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
info_p = db.performance
info_p.count_documents({})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[118]: 1583</div>

# %%
info_p
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[119]: Collection(Database(MongoClient(host=[&#39;cluster0-shard-00-02-t7ekj.mongodb.net:27017&#39;, &#39;cluster0-shard-00-01-t7ekj.mongodb.net:27017&#39;, &#39;cluster0-shard-00-00-t7ekj.mongodb.net:27017&#39;], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w=&#39;majority&#39;, authsource=&#39;admin&#39;, replicaset=&#39;Cluster0-shard-0&#39;, ssl=True), &#39;dataPI_db&#39;), &#39;performance&#39;)</div>

# %%
new_list = []
for t in test:
  nt = t.pop('_id')
  new_list.append(t)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_koalas = ks.DataFrame(new_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_koalas.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Away</th>
#       <th>Clash</th>
#       <th>D-1%</th>
#       <th>D-BH</th>
#       <th>D-BO</th>
#       <th>D-CG</th>
#       <th>D-CL</th>
#       <th>D-CM</th>
#       <th>D-CP</th>
#       <th>D-FA</th>
#       <th>D-FF</th>
#       <th>D-GA</th>
#       <th>D-GL</th>
#       <th>D-HB</th>
#       <th>D-HO</th>
#       <th>D-IF</th>
#       <th>D-KE</th>
#       <th>D-KI</th>
#       <th>D-MI</th>
#       <th>D-RB</th>
#       <th>D-TK</th>
#       <th>D-UP</th>
#       <th>F-1%</th>
#       <th>F-BH</th>
#       <th>F-BO</th>
#       <th>F-CG</th>
#       <th>F-CL</th>
#       <th>F-CM</th>
# ...

# %%
df_koalas['Winner'] = df_koalas['Winner'].replace({'Home': 0, 'Away': 1})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_koalas['Winner'] = df_koalas['Winner'].astype(int)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_koalas.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[149]: Away                     object
# Clash                     int64
# D-1%                    float64
# D-BH                    float64
# D-BO                    float64
# D-CG                    float64
# D-CL                    float64
# D-CM                    float64
# D-CP                    float64
# D-FA                    float64
# D-FF                    float64
# D-GA                    float64
# D-GL                    float64
# D-HB                    float64
# D-HO                    float64
# D-IF                    float64
# D-KE                    float64
# D-KI                    float64
# ...

# %%
categoricals = df_koalas[['Clash', 'Intrastate', 'Same / Neutral Venue']]
categoricalColumns = ['Clash', 'Intrastate', 'Same / Neutral Venue']


home_away_net = df_koalas.drop(['Away', 'Clash', 'Home', 'Intrastate', 'Net Score', 'RLP', 'Same / Neutral Venue', 'Season'])

# plt.figure(figsize = 15,15)
# sns.heatmap()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
categoricals.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Clash</th>
#       <th>Intrastate</th>
#       <th>Same / Neutral Venue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
# ...

# %%
home_away_net.head()

df = home_away_net
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X = home_away_net.iloc[:, :-1]

y = home_away_net['Winner']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X.head()

df = df_koalas[['D-1%', 'D-BO', 'D-CG', 'D-CM', 'D-IF', 'D-MI', 'F-BO', 'F-CM', 'F-FA', 'F-GA', 'F-KE', 'F-MI', 'F-RB', 'M-1%', 'M-GA', 'M-KE', 'M-RB', 'R-1%', 'R-BO', 'R-FF', 'R-GA', 'R-HB', 'R-HO', 'R-MI', 'R-RB', 'R-TK', 'R-UP', 'RLP', 'Same / Neutral Venue', 'Winner']]

df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D-1%</th>
#       <th>D-BO</th>
#       <th>D-CG</th>
#       <th>D-CM</th>
#       <th>D-IF</th>
#       <th>D-MI</th>
#       <th>F-BO</th>
#       <th>F-CM</th>
#       <th>F-FA</th>
#       <th>F-GA</th>
#       <th>F-KE</th>
#       <th>F-MI</th>
#       <th>F-RB</th>
#       <th>M-1%</th>
#       <th>M-GA</th>
#       <th>M-KE</th>
#       <th>M-RB</th>
#       <th>R-1%</th>
#       <th>R-BO</th>
#       <th>R-FF</th>
#       <th>R-GA</th>
#       <th>R-HB</th>
#       <th>R-HO</th>
#       <th>R-MI</th>
#       <th>R-RB</th>
#       <th>R-TK</th>
#       <th>R-UP</th>
#       <th>RLP</th>
# ...

# %%
# from pyspark.sql import SQLContext
# sqlContext = SQLContext(spark)

# df_sp = sqlContext.createDataFrame(new_list)

test = df.to_spark()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-----+-----+-----+------+-----+-----+-----+-----+-----+-------------------+-----+------+-----+-----+--------------------+-----+------+----+----+-----+------+------+-----+-----+-----+------+---+--------------------+------+
#   D-1%| D-BO| D-CG| D-CM|  D-IF| D-MI| F-BO| F-CM| F-FA| F-GA|               F-KE| F-MI|  F-RB| M-1%| M-GA|                M-KE| M-RB|  R-1%|R-BO|R-FF| R-GA|  R-HB|  R-HO| R-MI| R-RB| R-TK|  R-UP|RLP|Same / Neutral Venue|Winner|
# ...

# %%
# Ok, so let's try to understand what is happening with this code.

from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

stages = []

# I don't need to do this.  I am 
# for categoricalCol in categoricalColumns:
#   stringIndexer = StringIndexer(inputCol = categoricalCol, outputCol = categoricalCol + 'Index')
#   encoder = [categoricalCol + 'classVec']
#   stages += [stringIndexer, encoder]
  
label_stringIdx = StringIndexer(inputCol = 'Winner', outputCol = 'label')
stages += [label_stringIdx]

numericCols = ['D-1%', 'D-BO', 'D-CG', 'D-CM', 'D-IF', 'D-MI', 'F-BO', 'F-CM', 'F-FA', 'F-GA', 'F-KE', 'F-MI', 'F-RB', 'M-1%', 'M-GA', 'M-KE', 'M-RB', 'R-1%', 'R-BO', 'R-FF', 'R-GA', 'R-HB', 'R-HO', 'R-MI', 'R-RB', 'R-TK', 'R-UP', 'RLP']
# assemblerInputs = [c + "classVec" for c in categoricalColumns] + numericCols
assemblerInputs = numericCols
assembler = VectorAssembler(inputCols = assemblerInputs, outputCol = "features")
stages += [assembler]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[170]: [StringIndexer_26ca95b352cc, VectorAssembler_4e86322736a1]</div>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression

# This is from the DataBricks website example
partialPipeline = Pipeline().setStages(stages)
pipelineModel = partialPipeline.fit(test)
preppedDataDF = pipelineModel.transform(test)


# This is from the Medium article.  It breaks down a little bit.

# pipeline = Pipeline(stages = stages)
# pipelineModel = pipeline.fit(df)
# df = pipelineModel.transform(df)
# selectedCols = ['label', 'features'] + cols
# df = df.select(selectedCols)
# df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lrModel = LogisticRegression().fit(preppedDataDF)

display(lrModel, preppedDataDF, "ROC")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(lrModel, preppedDataDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
cols = test.columns
selectedcols = ['label', 'features'] + cols
dataset = preppedDataDF.select(selectedcols)
display(dataset)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
trainingData, testData = dataset.randomSplit([0.7, 0.3], seed = 100)
print(trainingData.count())
print(testData.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1102
# 481
# </div>

# %%
# Fit and Evaluate Models

lr = LogisticRegression(labelCol = 'label', featuresCol = 'features', maxIter = 10)

lrModel = lr.fit(trainingData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = lrModel.transform(testData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
selected = predictions.select('label', 'prediction', 'probability')
display(selected)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

evaluator = BinaryClassificationEvaluator(rawPredictionCol = 'rawPrediction')
evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[182]: 0.8023685127133404</div>
